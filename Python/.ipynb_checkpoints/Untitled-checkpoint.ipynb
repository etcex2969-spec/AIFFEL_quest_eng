# %%
                                                                                  다각형넓이 구하기

# %%
                                  Class사각형:               a=사각형
                                         def-init_(가로,세로)
                                         def area(self):
                                            return(self.가로,self.세로): 
                                             가로=5,세로=10
                                             넓이=(가로*세로)
                                             a.사각형=(5,10) 
                                            print("가로5 ,세로10 사각형의 넓이는", 사각형.area(), 입니다!")
