# %%
                                            <은행계좌만들기>

# %%
import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()import random

class Account:
    account_count = 0

    def __init__(self, owner, balance):
        self.bank = "SC은행"
        self.owner = owner
        self.balance = balance
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        
        # 계좌번호 생성
        p1 = random.randint(100, 999)
        p2 = random.randint(10, 99)
        p3 = random.randint(100000, 999999)
        self.account_number = f"{p1}-{p2}-{p3}"
        
        Account.account_count += 1

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount
            self.deposit_log.append(amount)
            self.deposit_count += 1
            if self.deposit_count % 5 == 0:
                interest = int(self.balance * 0.01)
                self.balance += interest
                print(f"★이자지급: {interest:,}원")
        else:
            print("1원 이상 입금 가능")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.withdraw_log.append(amount)
            print(f"{amount:,}원 출금 완료")
        else:
            print("잔액 부족")

    def display_info(self):
        print(f"은행: {self.bank}, 예금주: {self.owner}, 번호: {self.account_number}, 잔고: {self.balance:,}원")

# 테스트용 객체 생성
acc = Account("파이썬", 10000)
acc.display_info()
