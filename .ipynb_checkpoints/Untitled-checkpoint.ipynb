# %%
                      <  다각형넓이 구하기 >

# %%
            Class Square:
                       a=square
                   def_init_(self):
                   self.square=int(input('넓이를 구하는 square의숫자를써주세요'./n 1.직사각형2.평행사변형3.사다리꼴/n>>>)

# %%
                  if self.square==1:
                      print( '직사각형의 함수는  rec(5,10) 입니다')
                  class 직사각형:                                                a=직사각형
                     def-init-(width,height):
                     def area(self):
                         return(self.width*self.height)
                         a.rec=(5,10)
                           width=5            #가로와세로 변수설정
                           height=10 
                           area=width*height  #직사각형의넓이계산
                         print(f"가로5 ,세로10 직사각형의 넓이는 50 입니다")

# %%
                 if self.square==2:
                     print('평행사변형의 함수는 par(50,5)입니다')
                class 평행사변형:                                                a=평행사변형
                    def_init_(self,base,height):
                             self.base=base
                             self.height=height
                    def area(self):
                        return(self.base*self.height)
                        a.par=(50,5)
                        self.base=50                 #밑변과높이의 변수설정  
                        self.height=5
                        평행사변형.area=base*height    # 평행사변형의계산
                        
                    print(f"밑변50,높이5인 평행사변형의 넓이는 250 입니다")

# %%
                  if self.squre==3:
                      print('사다리꼴의 함수는 trap(10,20,5)입니다')
                class 사다리꼴:                                                   a=사다리꼴
                    def_init_(self,top,bottom,height):
                              self.top=top-side
                              self.bottom=bottom_side
                              self.height=height
                    def area(self):
                         return((self.top+self.bottom)*self.height/2)
                         a.trap=(10,20,5)
                         self.top=10
                         self.bottom=20
                         self.height=5
                         사다리꼴.area=(top_side+bottom_side)*height/2
                    print(f"윗변10 밑변20 높이5 인 사다리골의 함수는 75 입니다")

# %%
                                 < Koisk 만들기>

# %%
                         class koisk:
                             def__init__(self):
                        
                                 self.menu_data=["아메리카노",2500]
                                                 ["녹차",2500]
                                                ["카페라떼",3000]
                                 self.order_menue=[]
                                 self.order_price=[]
                                 self.temp=""
                             def menu_print(self):
                                 print("/n"+"="*20)
                                 print(" menupan")
                                 print("="*20)
                                 # 다차원리스트꺼네기
                             for i in range(len(self.menu_data))
#                                 # self.menu_data[i][0]은 이름,[ㅑ][0]은 가격입니다.
                                  name=self.menu_data[i][0]
                                  price=self.menu_data[i][1]
                                  print(f"{i+1}.{name}:{price}원")
                                 #주문 메서드
                             def menu_select(self):
                                 n=0
                                 While n <1 or n > len(self.menu_data):
                                     try:
                                         n=int(input("음료번호를 이력하세요:"))
                                         if 1 <=n=len(self.menu_data):
                                         # 선택한 데이타저장
                                         selected=self.menu_data[n-1]
                                         self.order_menu.append(selected[0])
                                         self.order_price.appended(selected[1])
                                     else:
                                         print("x없는 번호입니다.")
                               except ValueError:
                                    print("X 숫자만 입력하세요.")
